# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# Im always interested data science because, i wanted to learn various data visualization and data modeling techniques.

# %% [markdown]
# ### The Following Code will generate a random integer between 1 and 100

# %%
import random as rd

# %%
Random_int = rd.randint(1,100)

print(Random_int)
# Out:
# 99

# %% [markdown]
# Interested technologies:
# ***
# 1. Data Analytics
# 2. Cloud
# 3. Machine Learning
# 4. Data Engineeting
# ***

# %% [markdown]
# <a href="https://www.coursera.org/professional-certificates/ibm-data-science?utm_source=gg&utm_medium=sem&campaignid=8985360908&utm_campaign=10-IBM-Data-Science-IN&utm_content=B2C&adgroupid=86017337010&device=c&keyword=data%20science%20mooc&matchtype=b&network=g&devicemodel=&adpostion=&creativeid=519863395807&gclid=CjwKCAjw5NqVBhAjEiwAeCa97SiPzsC-ZdTN11ZDyvl_THLpSqTxj7ZBEPdLe6y7nHWpafXTKw68iBoCQpkQAvD_BwE">Data Science course</a>
